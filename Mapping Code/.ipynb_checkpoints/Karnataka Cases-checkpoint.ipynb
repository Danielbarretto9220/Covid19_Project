# %%
import json
import numpy as np
import pandas as pd
import plotly.express as px

# %%
import plotly.io as pio
pio.renderers.default = 'browser'

# %%
karnataka = json.load(open("karnataka.geojson", "r"))

# %%
dist_id_map = {}
for feature in karnataka["features"]:
    feature["id"] = feature["properties"]["pc_code"]
    dist_id_map[feature["properties"]["pc_name"]] = feature["id"]
dist_id_map
# Out:
# {'Koppal': 8,
#  'Haveri': 10,
#  'Davanagere': 13,
#  'Chikkaballapura': 27,
#  'Shimoga': 14,
#  'Hassan': 16,
#  'Bellary': 9,
#  'Udupi Chikmagalur': 15,
#  'Tumkur': 19,
#  'Kolar': 28,
#  'Bangalore Rural': 23,
#  'Chitradurga': 18,
#  'Bagalkot': 3,
#  'Bidar': 7,
#  'Uttara Kannada': 12,
#  'Bangalore North': 24,
#  'Mandya': 20,
#  'Gulbarga': 5,
#  'Bijapur': 4,
#  'Chikkodi': 1,
#  'Raichur': 6,
#  'Bangalore South': 26,
#  'Bangalore Central': 25,
#  'Dharwad': 11,
#  'Dakshina Kannada': 17,
#  'Mysore': 21,
#  'Chamrajnagar': 22,
#  'Belgaum': 2}

# %%
df = pd.read_csv('CovidData2.csv')
df["id"] = df["District Name"].apply(lambda x: dist_id_map[x])

# %%
df
# Out:
#         District Name  Today’s Positives  Total Positives  Today’s Discharges  \
# 0            Bagalkot                584            28584                1047
# 1             Bellary               1622            72677                3586
# 2             Belgaum               1502            45059                 614
# 3     Bangalore Rural               1265            43100                1318
# 4   Bangalore Central              13402          1042714                7379
# 5               Bidar                185            22612                 285
# 6        Chamrajnagar                535            20416                 793
# 7     Chikkaballapura                595            30249                 739
# 8         Chitradurga                454            20179                 207
# 9    Dakshina Kannada               1787            63357                1490
# 10         Davanagere                292            31846                 487
# 11            Dharwad                901            43043                 934
# 12             Hassan               2443            62199                1613
# 13             Haveri                267            16100                 282
# 14              Kolar                778            28610                 152
# 15             Koppal                630            24830                 653
# 16             Mandya               1188            50073                1202
# 17             Mysore               2489           110316                2338
# 18            Raichur                467            30680                 277
# 19            Shimoga               1081            39337                 647
# 20             Tumkur               2302            79341                1234
# 21  Udupi Chikmagalur               1146            45985                1496
# 22     Uttara Kannada               1226            31760                 935
#
#     Total Discharges  Total Active Cases  Today’s Reported Covid Deaths  \
# 0              21592                6753                             14
# 1              54112               17518                             28
# 2              34206               10464                              7
# 3              28499               14256                             10
# 4             666582              366791                             94
# 5              19510                2769                              6
# 6              15497                4634                              8
# 7              23242                6798                              5
# 8              17561                2516                              4
# 9              49355               13194                              3
# 10             28619                2916                              2
# 11             36554                5699                              8
# 12             46014               15491                             11
# 13             13985                1796                              6
# 14             22622                5727                              5
# 15             18902                5607                             10
# 16             41362                8377                             10
# 17             94053               14866                             15
# 18             22814                7653                              4
# 19             30926                7839                             15
# 20             51786               26877                             18
# 21             38466                7259                              7
# 22             24533                6875                              4
#
#     Total Covid Deaths  Death due to Non- Covid reasons  id
# 0                  239                                0   3
# 1                 1047                                0   9
# 2                  389                                0   2
# 3                  345                                0  23
# 4                 9340                                1  25
# 5                  329                                4   7
# 6                  274                               11  22
# 7                  208                                1  27
# 8                  102                                0  18
# 9                  806                                2  17
# 10                 311                                0  13
# 11                 789                                1  11
# 12                 693                                1  16
# 13                 319                                0  10
# 14                 261                                0  28
# 15                 321                                0   8
# 16                 334                                0  20
# 17                1397                                0  21
# 18                 213                                0   6
# 19                 572                                0  14
# 20                 678                                0  19
# 21                 260                                0  15
# 22                 352                                0  12

# %%
df["Total Active Cases"].plot()
# Out:
# <AxesSubplot:>

# %%
df["TSA Scaled"] = np.log10(df["Total Active Cases"])
df["TSA Scaled"].plot()
# Out:
# <AxesSubplot:>

# %%
fig = px.choropleth(
    df,
    locations="id",
    geojson=karnataka,
    color="TSA Scaled",
    hover_name="District Name",
    hover_data=["Total Active Cases"],
    title="Active Covid Cases in Karnatat",
)
fig.update_geos(fitbounds="locations", visible=False)
fig.show()
