# %%
# Code to extract specific districts from the excel files 
import pandas as pd
from datetime import date

# %%
tmp= pd.read_excel('EXCEL/01-03-2021.xlsx')

# %%
# date_df = pd.date_range(start='03/01/2021', end='05/27/2021')
# date = []
# import re
# for i in date_df:
#     i = str(i)
#     x = re.split("\s", i)
#     date.append(x[0])
# df = pd.DataFrame (columns = tmp.columns)
# #df['Date'] = date
# df.head()#
# Out:
# Empty DataFrame
# Columns: [District Name, Today’s Positives, Total Positives, Today’s Discharges, Total Discharges, Total Active Cases, Today’s Reported Covid Deaths, Total Covid Deaths, Death due to Non- Covid reasons]
# Index: []

# %%
# Code to extract specific districts from the excel files 
import pandas as pd
from datetime import date

date_df = pd.date_range(start='03/01/2021', end='05/27/2021')
tmp= pd.read_excel('EXCEL/01-03-2021.xlsx')
df = pd.DataFrame (columns = tmp.columns)

t=0
for i in date_df:
    target_date = i
    temp = str(target_date)[:10]
    result = temp.split("-")
    new_result = date(int(result[0]),int(result[1]),int(result[2]))
    month = new_result.strftime("%b").upper()
    year = result[0][2:]
    # date_requried = the date we'll be working on for each iteration 
    date_required = result[2] + "-" + result[1] + "-" + result[0]
    print('Working on the following day: ' + date_required)
    
    tmp= pd.read_excel('EXCEL/'+date_required+'.xlsx')
    tmp2 = tmp[tmp['District Name'] == 'Bengaluru Urban']
    x = re.split("\s", i)
    tmp2 

    df = pd.concat([df,tmp2])
# Out:
# Working on the following day: 01-03-2021
# Working on the following day: 02-03-2021
# Working on the following day: 03-03-2021
# Working on the following day: 04-03-2021
# Working on the following day: 05-03-2021
# Working on the following day: 06-03-2021
# Working on the following day: 07-03-2021
# Working on the following day: 08-03-2021
# Working on the following day: 09-03-2021
# Working on the following day: 10-03-2021
# Working on the following day: 11-03-2021
# Working on the following day: 12-03-2021
# Working on the following day: 13-03-2021
# Working on the following day: 14-03-2021
# Working on the following day: 15-03-2021
# Working on the following day: 16-03-2021
# Working on the following day: 17-03-2021
# Working on the following day: 18-03-2021
# Working on the following day: 19-03-2021
# Working on the following day: 20-03-2021
# Working on the following day: 21-03-2021
# Working on the following day: 22-03-2021
# Working on the following day: 23-03-2021
# ...

# %%
date_df = pd.date_range(start='03/01/2021', end='05/27/2021')
date = []
import re

for i in date_df:
    i = str(i)
    x = re.split("\s", i)
    date.append(x[0])

    
print(t)
t = 0
for i in date:
    t += 1
t
# Out:
# 88
# 88

# %%
df['Date'] = date
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-f416ab0d3e2d> in <module>
# ----> 1 df['Date'] = date
#
# c:\users\danie\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# c:\users\danie\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
#    3243         NDFrame._set_item(self, key, value)
#    3244
#
# ...

# %%
df
# Out:
#       District Name Today’s Positives Total Positives Today’s Discharges  \
# 4   Bengaluru Urban               210          405847                110
# 4   Bengaluru Urban               282          406129                159
# 4   Bengaluru Urban               311          406440                235
# 4   Bengaluru Urban               385          406825                310
# 4   Bengaluru Urban               444          407269                208
# ..              ...               ...             ...                ...
# 4   Bengaluru Urban              8214         1112058              36030
# 4   Bengaluru Urban              5701         1125253              34378
# 4   Bengaluru Urban              6243         1131496              13210
# 4   Bengaluru Urban              6433         1137929              18342
# 4   Bengaluru Urban              5949         1143878               6643
#
#    Total Discharges Total Active Cases Today’s Reported Covid Deaths  \
# ...
